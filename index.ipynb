# %% [markdown]
# # SQL Interview Questions  - Quiz
#
# ## Introduction
#
# In this lesson, we'll go through a short quiz containing the types of questions about SQL and relational databases that you can expect to see in an interview.
#
#
#
# ## SQL Interview Questions
#
# This quiz contains questions on topics you can expect to see in an interview pertaining to SQL and Relational Databases. Some of them are multiple choice, while some are short answer. For these short answer questions, double click on the Jupyter Notebook and type your answer below the line.
#
# ## Question 1
#
# what are the 4 main datatypes in SQLite3? Can we use other common types from other kinds of SQL?
#
# Type your answer below this line:
# text, integer, real, blob______________________________________________________________________________________________________________________________
#
#
#
#
#
# ## Question 2
#
# Explain the relationship between **Primary Keys** and **Foreign Keys**.
#
# Type your answer below this line:
# __Primary keys uniquely identify rows within a table.  Foreign keys are the primary keys of other tables.  They can be used to join between the tables._____________________________________________________________________________________________________________________________
#
#
#
#
#
# ## Question 3
#
# Explain the different types of relationships entities can have in a SQL database.
#
# Type your answer below this line:
# __One-to-one: one row matches to one row in the other table.
# One-to-many: One row matches to many rows in another table (for instance a Customer matching to the customer's orders in another table.
#
# Many-to-many : one or more rows matching to one or more rows in another table.
# _____________________________________________________________________________________________________________________________
#
#
# ## Question 4
#
# Explain the various types of JOINs possible with SQL.
#
# Type your answer below this line:
# _JOIN (inner join): keeps matches from both tables.
# Left (or right) Join - keeps all from left and matches from right.
# Outer Join - keeps all from both, regardless of whether they matched._
# Left Anti-Join - keeps any from left that are not matched in right
# Anti-Union - keep all from left and right except those in both._____________________________________________________________________________________________________________________________
#
#
#
# ## Question 5
#
# Explain the relationship between Aggregate functions and GROUP BY statements.
#
# Type your answer below this line:
# _Aggregate functions are calculations performed on fields after, generally after reflecting a GROUP BY statement.
#
# The GROUP BY statement makes groups based on a condition, upon which aggregations can be applied, or ?HAVING conditions can be used as filters.______________________________________________________________________________________________________________________________
#
#
#
# ## Question 6
#
# What role do Associative Entities play (JOIN Tables) in many-to-many JOINs?
#
#
# Type your answer below this line:
# _Associative entities help bridge many to many joins.  They create a bridge of foreign keys that aren't connected between two tables.______________________________________________________________________________________________________________________________
#
#
#
# ## Summary
#
# In this lesson, we practiced answering open-ended interview questions for SQL and Relational Databases.
